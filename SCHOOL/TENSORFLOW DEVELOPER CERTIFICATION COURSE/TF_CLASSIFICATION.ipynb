# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.11.0

# %%
 devices = tf.config.list_physical_devices()
print(devices)
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
from sklearn.datasets import make_circles

# %%
n_samples = 1000

X, y = make_circles(n_samples,
                   noise=0.03,
                   random_state=42)

# %%
X
# Out:
# array([[ 0.75424625,  0.23148074],
#        [-0.75615888,  0.15325888],
#        [-0.81539193,  0.17328203],
#        ...,
#        [-0.13690036, -0.81001183],
#        [ 0.67036156, -0.76750154],
#        [ 0.28105665,  0.96382443]])

# %%
y[:10]
# Out:
# array([1, 1, 1, 1, 0, 1, 1, 1, 1, 0])

# %%
# Make dataframe of features and labels
import pandas as pd
circles = pd.DataFrame({"X0":X[:, 0], "X1":X[:, 1], "label":y})
circles.head()
# Out:
#          X0        X1  label
# 0  0.754246  0.231481      1
# 1 -0.756159  0.153259      1
# 2 -0.815392  0.173282      1
# 3 -0.393731  0.692883      1
# 4  0.442208 -0.896723      0

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1], c=y, cmap=plt.cm.RdYlBu)

# %%
plt.show()

# %%
X.shape, y.shape
# Out:
# ((1000, 2), (1000,))

# %%
X[4], y[4]
# Out:
# (array([ 0.44220765, -0.89672343]), 0)

# %%
tf.random.set_seed(42)
model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(1)   
])
model_1.compile(loss=tf.keras.losses.BinaryCrossentropy(),
               optimizer=tf.keras.optimizers.SGD(),
               metrics=['accuracy'])

# %%
model_1.fit(X,y,epochs=200,verbose=0)

# %%
model_1.evaluate(X,y)
# Out:
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6935 - accuracy: 0.5000
# [0.6934829950332642, 0.5]

# %%
tf.random.set_seed(42)
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(1),
    tf.keras.layers.Dense(1)
])
model_2.compile(loss=tf.keras.losses.BinaryCrossentropy(),
               optimizer=tf.keras.optimizers.SGD(),
               metrics=['accuracy'])

# %%
model_1.fit(X,y,epochs=200,verbose=0)
model_1.evaluate(X,y)
# Out:
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6935 - accuracy: 0.5000
# [0.6934829950332642, 0.5]

# %%
tf.random.set_seed(42)
model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(1)
])
model_3.compile(loss=tf.keras.losses.BinaryCrossentropy(),
               optimizer=tf.keras.optimizers.Adam(),
               metrics=['accuracy'])

# %%
model_2.fit(X,y,epochs=100,verbose=0)
model_2.evaluate(X,y)
# Out:
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6933 - accuracy: 0.5000
# [0.6932619214057922, 0.5]

# %%
import numpy as np

import numpy as np

def plot_decision_boundary(model, X, y):
    
    """
    Plots the decision boundary created by a model predicting on X.
    This function has been adapted from two phenomenal resources:
     1. CS231n - https://cs231n.github.io/neural-networks-case-study/
     2. Made with ML basics - https://github.com/GokuMohandas/MadeWithML/blob/main/notebooks/08_Neural_Networks.ipynb
    """
    # Define the axis boundaries of the plot and create a meshgrid
    x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
    y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                           np.linspace(y_min, y_max, 100))

    # Create X values (we're going to predict on all of these)
    x_in = np.c_[xx.ravel(), yy.ravel()] # stack 2D arrays together: https://numpy.org/devdocs/reference/generated/numpy.c_.html

    # Make predictions using the trained model
    y_pred = model.predict(x_in)

    # Check for multi-class
    if model.output_shape[-1] > 1:
        # checks the final dimension of the model's output shape, if this is > (greater than) 1, it's multi-class 
        print("doing multiclass classification...")
        # We have to reshape our predictions to get them ready for plotting
        y_pred = np.argmax(y_pred, axis=1).reshape(xx.shape)
    else:
        print("doing binary classifcation...")
        y_pred = np.round(np.max(y_pred, axis=1)).reshape(xx.shape)

    # Plot decision boundary
    plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7)
    plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.show()

# %%
plot_decision_boundary(model_3, X, y)
plot_decision_boundary
# Out:
# 313/313 [==============================] - 0s 884us/step
# doing binary classifcation...
# <function __main__.plot_decision_boundary(model, X, y)>

# %%
# Set random seed
tf.random.set_seed(42)

# Create some regression data
X_regression = np.arange(0, 1000, 5)
y_regression = np.arange(100, 1100, 5)

# Split it into training and test sets
X_reg_train = X_regression[:150]
X_reg_test = X_regression[150:]
y_reg_train = y_regression[:150]
y_reg_test = y_regression[150:]

# After TensorFlow 2.7.0, see here for more: https://github.com/mrdbourke/tensorflow-deep-learning/discussions/278
model_3.fit(tf.expand_dims(X_reg_train, axis=-1), 
            y_reg_train,
            epochs=100)
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [43], line 15
#      12 y_reg_test = y_regression[150:]
#      14 # After TensorFlow 2.7.0, see here for more: https://github.com/mrdbourke/tensorflow-deep-learning/discussions/278
# ---> 15 model_3.fit(tf.expand_dims(X_reg_train, axis=-1),
#      16             y_reg_train,
#      17             epochs=100)
#
# File ~/.conda/envs/BIGAI/lib/python3.9/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/.conda/envs/BIGAI/lib/python3.9/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:921, in Function._call(self, *args, **kwds)
#     919   results = self._variable_creation_fn(*args, **kwds)
#     920   if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
# --> 921     raise ValueError("Creating variables on a non-first call to a function"
#     922                      " decorated with tf.function.")
#     923   return results
#     925 try:
#     926   # This is the first call of __call__, so we have to initialize.
#
# ValueError: Creating variables on a non-first call to a function decorated with tf.function.

# %%
model_3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 100)               300
#
#  dense_4 (Dense)             (None, 10)                1010
#
#  dense_5 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 1,321
# Trainable params: 1,321
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.random.set_seed(42)
model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(1)
])
model_3.compile(loss=tf.keras.losses.mae,
               optimizer=tf.keras.optimizers.Adam(),
               metrics=['mae'])

# %%
# Set the random seed
tf.random.set_seed(42)

# Create the model
model_4 = tf.keras.Sequential([
  tf.keras.layers.Dense(1, activation=tf.keras.activations.linear), # 1 hidden layer with linear activation
  tf.keras.layers.Dense(1) # output layer
])

# Compile the model
model_4.compile(loss=tf.keras.losses.binary_crossentropy,
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), # note: "lr" used to be what was used, now "learning_rate" is favoured
                metrics=["accuracy"])

# Fit the model
history = model_4.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 1ms/step - loss: 4.3076 - accuracy: 0.4300
# Epoch 2/100
# 32/32 [==============================] - 0s 1ms/step - loss: 4.2022 - accuracy: 0.4440
# Epoch 3/100
# 32/32 [==============================] - 0s 1ms/step - loss: 4.1240 - accuracy: 0.4470
# Epoch 4/100
# 32/32 [==============================] - 0s 1ms/step - loss: 4.0467 - accuracy: 0.4460
# Epoch 5/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.8942 - accuracy: 0.4440
# Epoch 6/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.8402 - accuracy: 0.4460
# Epoch 7/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.8168 - accuracy: 0.4460
# Epoch 8/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.8015 - accuracy: 0.4450
# Epoch 9/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.7876 - accuracy: 0.4460
# Epoch 10/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.7257 - accuracy: 0.4440
# Epoch 11/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.6943 - accuracy: 0.4450
# Epoch 12/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.6122 - accuracy: 0.4430
# Epoch 13/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.4832 - accuracy: 0.4360
# Epoch 14/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.3855 - accuracy: 0.4290
# Epoch 15/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.3544 - accuracy: 0.4280
# Epoch 16/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.2776 - accuracy: 0.4270
# Epoch 17/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.2015 - accuracy: 0.4160
# Epoch 18/100
# 32/32 [==============================] - 0s 1ms/step - loss: 3.0276 - accuracy: 0.4150
# Epoch 19/100
# 32/32 [==============================] - 0s 1ms/step - loss: 2.7609 - accuracy: 0.4150
# Epoch 20/100
# 32/32 [==============================] - 0s 1ms/step - loss: 2.0374 - accuracy: 0.4440
# Epoch 21/100
# 32/32 [==============================] - 0s 3ms/step - loss: 1.1123 - accuracy: 0.4630
# Epoch 22/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0690 - accuracy: 0.4630
# Epoch 23/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0540 - accuracy: 0.4650
# Epoch 24/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0428 - accuracy: 0.4650
# Epoch 25/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0328 - accuracy: 0.4710
# Epoch 26/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0241 - accuracy: 0.4710
# Epoch 27/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0162 - accuracy: 0.4720
# Epoch 28/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0088 - accuracy: 0.4730
# Epoch 29/100
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0024 - accuracy: 0.4770
# Epoch 30/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9962 - accuracy: 0.4780
# Epoch 31/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9903 - accuracy: 0.4790
# Epoch 32/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9848 - accuracy: 0.4810
# Epoch 33/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9796 - accuracy: 0.4810
# Epoch 34/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9748 - accuracy: 0.4810
# Epoch 35/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9702 - accuracy: 0.4840
# Epoch 36/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9658 - accuracy: 0.4840
# Epoch 37/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9614 - accuracy: 0.4860
# Epoch 38/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9573 - accuracy: 0.4860
# Epoch 39/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9533 - accuracy: 0.4870
# Epoch 40/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9495 - accuracy: 0.4870
# Epoch 41/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9457 - accuracy: 0.4880
# Epoch 42/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9420 - accuracy: 0.4880
# Epoch 43/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9384 - accuracy: 0.4880
# Epoch 44/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9351 - accuracy: 0.4880
# Epoch 45/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9317 - accuracy: 0.4880
# Epoch 46/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9285 - accuracy: 0.4900
# Epoch 47/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9254 - accuracy: 0.4900
# Epoch 48/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9222 - accuracy: 0.4910
# Epoch 49/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9191 - accuracy: 0.4910
# Epoch 50/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9161 - accuracy: 0.4910
# Epoch 51/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9131 - accuracy: 0.4910
# Epoch 52/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9102 - accuracy: 0.4920
# Epoch 53/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9073 - accuracy: 0.4940
# Epoch 54/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9045 - accuracy: 0.4940
# Epoch 55/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9017 - accuracy: 0.4940
# Epoch 56/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8990 - accuracy: 0.4940
# Epoch 57/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8964 - accuracy: 0.4950
# Epoch 58/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8938 - accuracy: 0.4950
# Epoch 59/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8912 - accuracy: 0.4950
# Epoch 60/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8886 - accuracy: 0.4950
# Epoch 61/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8860 - accuracy: 0.4950
# Epoch 62/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8837 - accuracy: 0.4950
# Epoch 63/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8811 - accuracy: 0.4950
# Epoch 64/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8787 - accuracy: 0.4950
# Epoch 65/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8764 - accuracy: 0.4950
# Epoch 66/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8740 - accuracy: 0.4950
# Epoch 67/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8718 - accuracy: 0.4950
# Epoch 68/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8695 - accuracy: 0.4950
# Epoch 69/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8672 - accuracy: 0.4950
# Epoch 70/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8650 - accuracy: 0.4950
# Epoch 71/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8628 - accuracy: 0.4950
# Epoch 72/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8606 - accuracy: 0.4950
# Epoch 73/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8585 - accuracy: 0.4950
# Epoch 74/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8564 - accuracy: 0.4950
# Epoch 75/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8543 - accuracy: 0.4950
# Epoch 76/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8522 - accuracy: 0.4950
# Epoch 77/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8502 - accuracy: 0.4950
# Epoch 78/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8481 - accuracy: 0.4950
# Epoch 79/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8461 - accuracy: 0.4950
# Epoch 80/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8440 - accuracy: 0.4950
# Epoch 81/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8420 - accuracy: 0.4950
# Epoch 82/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8401 - accuracy: 0.4950
# Epoch 83/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8382 - accuracy: 0.4950
# Epoch 84/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8363 - accuracy: 0.4950
# Epoch 85/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8344 - accuracy: 0.4950
# Epoch 86/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8325 - accuracy: 0.4950
# Epoch 87/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8306 - accuracy: 0.4950
# Epoch 88/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.8289 - accuracy: 0.4950
# Epoch 89/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8271 - accuracy: 0.4950
# Epoch 90/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8253 - accuracy: 0.4950
# Epoch 91/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8235 - accuracy: 0.4950
# Epoch 92/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8217 - accuracy: 0.4950
# Epoch 93/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8200 - accuracy: 0.4950
# Epoch 94/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8183 - accuracy: 0.4950
# Epoch 95/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8165 - accuracy: 0.4950
# Epoch 96/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8148 - accuracy: 0.4950
# Epoch 97/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8131 - accuracy: 0.4950
# Epoch 98/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8114 - accuracy: 0.4950
# Epoch 99/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8097 - accuracy: 0.4950
# Epoch 100/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8080 - accuracy: 0.4940

# %%
# Set random seed
tf.random.set_seed(42)

# Create a model with a non-linear activation
model_5 = tf.keras.Sequential([
  tf.keras.layers.Dense(1, activation=tf.keras.activations.relu), # can also do activation='relu'
  tf.keras.layers.Dense(1) # output layer 
])

# Compile the model
model_5.compile(loss=tf.keras.losses.binary_crossentropy,
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

# Fit the model
history = model_5.fit(X, y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 2/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 3/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 4/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 5/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 6/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 7/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 8/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 9/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 10/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 11/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 12/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 13/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 14/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 15/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 16/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 17/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 18/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 19/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 20/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 21/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 22/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 23/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 24/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 25/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 26/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 27/100
# 32/32 [==============================] - 0s 2ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 28/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 29/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 30/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 31/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 32/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 33/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 34/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 35/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 36/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 37/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 38/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 39/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 40/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 41/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 42/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 43/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 44/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 45/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 46/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 47/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 48/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 49/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 50/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 51/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 52/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 53/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 54/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 55/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 56/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 57/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 58/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 59/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 60/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 61/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 62/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 63/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 64/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 65/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 66/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 67/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 68/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 69/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 70/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 71/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 72/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 73/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 74/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 75/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 76/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 77/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 78/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 79/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 80/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 81/100
# 32/32 [==============================] - 0s 2ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 82/100
# 32/32 [==============================] - 0s 2ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 83/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 84/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 85/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 86/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 87/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 88/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 89/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 90/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 91/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 92/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 93/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 94/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 95/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 96/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 97/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 98/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 99/100
# 32/32 [==============================] - 0s 1ms/step - loss: 7.7125 - accuracy: 0.5000
# Epoch 100/100
# 32/32 [==============================] - 0s 3ms/step - loss: 7.7125 - accuracy: 0.5000

# %%
tf.random.set_seed(42)

model_6 = tf.keras.Sequential([
    tf.keras.layers.Dense(12, activation=tf.keras.activations.relu),
    tf.keras.layers.Dense(12, activation=tf.keras.activations.relu),
    tf.keras.layers.Dense(1, activation=tf.keras.activations.sigmoid)    
])

# %%
model_6.compile(loss=tf.keras.losses.binary_crossentropy,
               optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
               metrics=['accuracy'])

# %%
history = model_6.fit(X, y, epochs=250,verbose=0)

# %%
model_6.evaluate(X, y)
# Out:
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0019 - accuracy: 1.0000
# [0.0018574806163087487, 1.0]

# %%
plot_decision_boundary(model_6, X, y)
# Out:
# 313/313 [==============================] - 0s 815us/step
# doing binary classifcation...

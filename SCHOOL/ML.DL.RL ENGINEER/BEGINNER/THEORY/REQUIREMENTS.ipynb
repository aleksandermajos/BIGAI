# %%
from ENGINE.ALL.UTILS.python_environment_check import check_packages
from ENGINE.ALL.UTILS.detect_gpu_pytorch import detect_gpu_pytorch
from IPython.display import Image
import sys
sys.path.insert(0, '..')

# %%
d = {
    'numpy': '1.21.2',
    'scipy': '1.7.0',
    'matplotlib': '3.4.3',
    'sklearn': '1.0',
    'pandas': '1.3.2',
    'torch': '1.8.0',
    'torchvision': '0.9.0'
}
check_packages(d)
# Out:
# [OK] numpy 1.21.5
# [OK] scipy 1.8.0
# [OK] matplotlib 3.5.1
# [OK] sklearn 1.0.2
# [OK] pandas 1.4.1
# [OK] torch 1.12.0.dev20220406+cu113
# [OK] torchvision 0.12.0+cpu

# %%
detect_gpu_pytorch()
# Out:
# IS AVAILABLE? :
# True
# HOW MANY DEVICES? :
# 2
# NVIDIA GeForce RTX 3060
# Allocated: 0.0 GB
# Cached:    0.0 GB
# NVIDIA GeForce RTX 2060
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %% [markdown]
# # DO YOU SEE A PIC?

# %%
Image(filename='./FIGURES/ML_FLOW.png', width=800)

# %%
Image(filename='./FIGURES/ML_FLOW.png', width=800)
